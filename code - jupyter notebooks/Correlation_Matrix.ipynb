# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import  numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('dft-road-casualty-statistics-collision-last-5-years (1).csv')
#df

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'accident_severity', 'number_of_vehicles',
#        'number_of_casualties', 'day_of_week', 'first_road_class',
#        'first_road_number', 'road_type', 'speed_limit', 'junction_detail',
#        'junction_control', 'second_road_class', 'second_road_number',
#        'pedestrian_crossing_human_control',
#        'pedestrian_crossing_physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident',
#        'trunk_road_flag'],
#       dtype='object')

# %%
df.head()
# Out:
#    longitude   latitude  accident_severity  number_of_vehicles  \
# 0  -0.139737  51.524587                  3                   2
# 1   0.046471  51.539651                  3                   1
# 2  -0.102474  51.529746                  3                   2
# 3   0.037828  51.530179                  2                   2
# 4   0.065781  51.469258                  2                   2
#
#    number_of_casualties  day_of_week  first_road_class  first_road_number  \
# 0                     2            2                 3                501
# 1                     1            2                 4                165
# 2                     1            2                 3                  1
# 3                     1            2                 4                167
# 4                     2            2                 3                207
#
#    road_type  speed_limit  ...  pedestrian_crossing_human_control  \
# 0          3           30  ...                                  0
# ...

# %%
# Compute the correlation matrix
corr_matrix = df.corr()
#corr_matrix
# Plot the correlation matrix
plt.figure(figsize=(20, 20))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, mask=mask)
plt.title('Correlation Matrix')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['speed_limit', 'road_type', 'first_road_class', 'first_road_number','junction_detail','second_road_class','number_of_casualties']
df_selected = df[selected_columns]

# Calculate the correlation matrix using the Spearman method
corr_matrix = df_selected.corr(method='spearman')
# Plot the correlation matrix
plt.figure(figsize=(7,7))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix: Speed limit vs road_type, first_road_class, first_road_number, junction_detail, second_road_class, number_of_casualties')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['pedestrian_crossing_human_control','pedestrian_crossing_physical_facilities','junction_control','did_police_officer_attend_scene_of_accident']
df_selected = df[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix: Pedestrian and Traffic Control')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['pedestrian_crossing_human_control','pedestrian_crossing_physical_facilities','junction_control','did_police_officer_attend_scene_of_accident','number_of_casualties']
df_selected = df[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix: Pedestrian and Traffic Control')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['number_of_casualties','light_conditions', 'weather_conditions','road_surface_conditions','carriageway_hazards','number_of_casualties','accident_severity']
df_selected = df[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix:  Casualties vs Different Conditions')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['number_of_casualties','light_conditions', 'weather_conditions','road_surface_conditions','carriageway_hazards']
df_selected = df[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix:  Casualties vs Different Conditions')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.read_csv('casualty_dataset.csv')

selected_columns = ['sex_of_casualty','age_of_casualty','casualty_class']
df_selected = df1[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix: Casualty class vs Casualty age & sex')
plt.show()

# %%
df1.columns
# Out:
# Index(['accident_index', 'accident_year', 'accident_reference',
#        'vehicle_reference', 'casualty_reference', 'casualty_class',
#        'sex_of_casualty', 'age_of_casualty', 'age_band_of_casualty',
#        'casualty_severity', 'pedestrian_location', 'pedestrian_movement',
#        'car_passenger', 'bus_or_coach_passenger',
#        'pedestrian_road_maintenance_worker', 'casualty_type',
#        'casualty_home_area_type', 'casualty_imd_decile', 'lsoa_of_casualty'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.read_csv('casualty_dataset.csv')

selected_columns = ['sex_of_casualty','age_of_casualty','casualty_class','casualty_severity']
df_selected = df1[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix: Casualty class vs Casualty age & sex')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.read_csv('casualty_dataset.csv')

selected_columns = ['casualty_class','casualty_severity','casualty_type','casualty_imd_decile','casualty_home_area_type']
df_selected = df1[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix: Casualty severity vs Casualty type, class, imd_decile & area type')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.read_csv('casualty_dataset.csv')

selected_columns = ['casualty_class','casualty_severity','casualty_type','casualty_imd_decile','casualty_home_area_type']
df_selected = df1[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix: Casualty severity vs Casualty type, class, imd_decile & area type')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df2 = pd.read_csv('vehicle_dataset.csv')

selected_columns = ['age_of_driver','sex_of_driver', 'driver_imd_decile', 'driver_home_area_type']
df_selected = df2[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix: Correlation between Drivers age, sex, imd_decile & area type')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df2 = pd.read_csv('vehicle_dataset.csv')

selected_columns = ['age_of_driver','sex_of_driver', 'driver_imd_decile', 'driver_home_area_type']
df_selected = df2[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix: Correlation between Drivers age, sex, imd_decile & area type')
plt.show()

# %%
df2.columns
# Out:
# Index(['accident_index', 'accident_year', 'accident_reference',
#        'vehicle_reference', 'vehicle_type', 'towing_and_articulation',
#        'vehicle_manoeuvre', 'vehicle_direction_from', 'vehicle_direction_to',
#        'vehicle_location_restricted_lane', 'junction_location',
#        'skidding_and_overturning', 'hit_object_in_carriageway',
#        'vehicle_leaving_carriageway', 'hit_object_off_carriageway',
#        'first_point_of_impact', 'vehicle_left_hand_drive',
#        'journey_purpose_of_driver', 'sex_of_driver', 'age_of_driver',
#        'age_band_of_driver', 'engine_capacity_cc', 'propulsion_code',
#        'age_of_vehicle', 'generic_make_model', 'driver_imd_decile',
#        'driver_home_area_type', 'lsoa_of_driver'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df2 = pd.read_csv('vehicle_dataset.csv')

selected_columns = ['vehicle_leaving_carriageway','hit_object_in_carriageway', 'hit_object_off_carriageway', 'skidding_and_overturning']
df_selected = df2[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix: Accident Circumstances')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df2 = pd.read_csv('vehicle_dataset.csv')

selected_columns = ['vehicle_leaving_carriageway','hit_object_in_carriageway', 'hit_object_off_carriageway', 'skidding_and_overturning']
df_selected = df2[selected_columns]

# Calculate the correlation matrix using Spearman method
corr_matrix = df_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(5, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix: Accident Circumstances')
plt.show()
